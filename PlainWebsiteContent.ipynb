# %% [markdown]
# <a href="https://colab.research.google.com/github/vijaykrishnadodla/stb-website/blob/main/PlainWebsiteContent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

url = "https://studenttravelbuddy.com"
headers = {
    "User-Agent": "Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

for tag in soup(["script", "style", "noscript"]):
    tag.decompose()

text = soup.get_text(separator="\n")
text = "\n".join(line.strip() for line in text.splitlines() if line.strip())

# Display the result
print(text)
# Out:
# Student Travel Buddy - Gen Z Travel Guide
# STUDENT TRAVEL BUDDY
# Travel Quiz
# Free Resources
# The Sunshine Club
# Our Story
# Ambassadors
# Join Now
# @STUDENTTRAVELBUDDYOFFICIAL
# TRAVEL
# BRIGHTER.
# SPEND
# SMARTER.
# The ultimate travel sidekick for students - with Sunny by your side!
# Join thousands of students saving on average
# $200+ per week
# while traveling with our exclusive membership perks.
# Find Your Travel Style
# Join The Sunshine Club
# 🌞
# ✈️
# 👋
# Joined by
# 5,000+
# student travelers
# Popular Student Destinations Trending in 2025:
# Cancún
# Paris
# London
# Rome
# Barcelona
# LA
# NY
# Chicago
# Honolulu
# Dublin
# Tokyo
# "You pack the snacks, I'll plan the vibe" ☀️
# meet SUNNY your new travel BESTIE!
# Join Free
# Start your sunny adventure today!
# Student Travel Style Quiz
# Discover your travel vibe + unlock exclusive perks!
# Let's find your ideal destination! 🌍
# Ready for an Adventure? 🚀
# ...
